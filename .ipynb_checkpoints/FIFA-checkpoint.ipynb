# %%
import pandas as pd
dataframe = pd.read_csv('fifa21_train.csv')
dataframe
# Out:
#            ID            Name  Age  Nationality                        Club  \
# 0      184383       A. Pasche   26  Switzerland           FC Lausanne-Sport
# 1      188044   Alan Carvalho   30     China PR     Beijing Sinobo Guoan FC
# 2      184431     S. Giovinco   33        Italy                    Al Hilal
# 3      233796        J. Evans   22        Wales                Swansea City
# 4      234799      Y. Demoncy   23       France  US Orléans Loiret Football
# ...       ...             ...  ...          ...                         ...
# 11696  232504   B. Böðvarsson   25      Iceland       Jagiellonia Białystok
# 11697  214680       G. Gallon   27       France                ESTAC Troyes
# 11698  221489       J. Flores   22        Chile              CD Antofagasta
# 11699  146717  Anderson Silva   26       Brazil                    Barnsley
# 11700  236507     T. Conechny   22    Argentina            Portland Timbers
#
# ...

# %%
dataframe.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Club', 'BP', 'Position',
#        'Team & Contract', 'Height', 'Weight',
#        ...
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'GK', 'OVA'],
#       dtype='object', length=101)

# %%
dataframe.columns = dataframe.columns.str.replace(' ', '_').str.lower()
dataframe.columns
# Out:
# Index(['id', 'name', 'age', 'nationality', 'club', 'bp', 'position',
#        'team_&_contract', 'height', 'weight',
#        ...
#        'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb', 'gk', 'ova'],
#       dtype='object', length=101)

# %%
dataframe.head(10)
# Out:
#        id           name  age         nationality  \
# 0  184383      A. Pasche   26         Switzerland
# 1  188044  Alan Carvalho   30            China PR
# 2  184431    S. Giovinco   33               Italy
# 3  233796       J. Evans   22               Wales
# 4  234799     Y. Demoncy   23              France
# 5  182411     Yu Hanchao   33            China PR
# 6  184392     M. Darmian   30               Italy
# 7  257768       N. Mosti   22               Italy
# 8  225013      M. Čovilo   34  Bosnia Herzegovina
# 9  179698       L. Grimi   35           Argentina
#
#                             club   bp  position  \
# 0              FC Lausanne-Sport   CM    CM CDM
# 1        Beijing Sinobo Guoan FC   ST  ST LW LM
# 2                       Al Hilal  CAM    CAM CF
# 3                   Swansea City  CDM    CDM CM
# 4     US Orléans Loiret Football  CDM    CDM CM
# 5  Shanghai Greenland Shenhua FC   LM  LM LW RW
# 6                          Parma   RB     RB LB
# ...

# %%
pd.set_option('display.max_columns', None)
dataframe.head()
# Out:
#        id           name  age  nationality                        club   bp  \
# 0  184383      A. Pasche   26  Switzerland           FC Lausanne-Sport   CM
# 1  188044  Alan Carvalho   30     China PR     Beijing Sinobo Guoan FC   ST
# 2  184431    S. Giovinco   33        Italy                    Al Hilal  CAM
# 3  233796       J. Evans   22        Wales                Swansea City  CDM
# 4  234799     Y. Demoncy   23       France  US Orléans Loiret Football  CDM
#
#    position                               team_&_contract height  weight  \
# 0    CM CDM                 FC Lausanne-Sport 2015 ~ 2020   5'9"  161lbs
# 1  ST LW LM  Beijing Sinobo Guoan FC Dec 31, 2020 On Loan   6'0"  159lbs
# 2    CAM CF                          Al Hilal 2019 ~ 2022   5'4"  134lbs
# 3    CDM CM                      Swansea City 2016 ~ 2021  5'10"  152lbs
# 4    CDM CM        US Orléans Loiret Football 2018 ~ 2021  5'11"  150lbs
#
# ...

# %%
dataframe = dataframe.drop_duplicates()
dataframe.isna().sum()
# Out:
# id              0
# name            0
# age             0
# nationality     0
# club           18
#                ..
# cb              0
# rcb             0
# rb              0
# gk              0
# ova             0
# Length: 101, dtype: int64

# %%
dataframe.columns
# Out:
# Index(['id', 'name', 'age', 'nationality', 'club', 'bp', 'position',
#        'team_&_contract', 'height', 'weight', 'foot', 'growth', 'joined',
#        'loan_date_end', 'value', 'wage', 'release_clause', 'contract',
#        'attacking', 'crossing', 'finishing', 'heading_accuracy',
#        'short_passing', 'volleys', 'skill', 'dribbling', 'curve',
#        'fk_accuracy', 'long_passing', 'ball_control', 'movement',
#        'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance',
#        'power', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots',
#        'mentality', 'aggression', 'interceptions', 'positioning', 'vision',
#        'penalties', 'composure', 'defending', 'marking', 'standing_tackle',
#        'sliding_tackle', 'goalkeeping', 'gk_diving', 'gk_handling',
#        'gk_kicking', 'gk_positioning', 'gk_reflexes', 'total_stats',
#        'base_stats', 'w/f', 'sm', 'a/w', 'd/w', 'ir', 'pac', 'sho', 'pas',
# ...

# %%
dataframe = dataframe.drop(columns=['ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf',
       'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm'])
dataframe.columns
# Out:
# Index(['id', 'name', 'age', 'nationality', 'club', 'bp', 'position',
#        'team_&_contract', 'height', 'weight', 'foot', 'growth', 'joined',
#        'loan_date_end', 'value', 'wage', 'release_clause', 'contract',
#        'attacking', 'crossing', 'finishing', 'heading_accuracy',
#        'short_passing', 'volleys', 'skill', 'dribbling', 'curve',
#        'fk_accuracy', 'long_passing', 'ball_control', 'movement',
#        'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance',
#        'power', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots',
#        'mentality', 'aggression', 'interceptions', 'positioning', 'vision',
#        'penalties', 'composure', 'defending', 'marking', 'standing_tackle',
#        'sliding_tackle', 'goalkeeping', 'gk_diving', 'gk_handling',
#        'gk_kicking', 'gk_positioning', 'gk_reflexes', 'total_stats',
#        'base_stats', 'w/f', 'sm', 'a/w', 'd/w', 'ir', 'pac', 'sho', 'pas',
#        'dri', 'def', 'phy', 'hits', 'ova'],
# ...

# %%
dataframe.head()
# Out:
#        id           name  age  nationality                        club   bp  \
# 0  184383      A. Pasche   26  Switzerland           FC Lausanne-Sport   CM
# 1  188044  Alan Carvalho   30     China PR     Beijing Sinobo Guoan FC   ST
# 2  184431    S. Giovinco   33        Italy                    Al Hilal  CAM
# 3  233796       J. Evans   22        Wales                Swansea City  CDM
# 4  234799     Y. Demoncy   23       France  US Orléans Loiret Football  CDM
#
#    position                               team_&_contract height  weight  \
# 0    CM CDM                 FC Lausanne-Sport 2015 ~ 2020   5'9"  161lbs
# 1  ST LW LM  Beijing Sinobo Guoan FC Dec 31, 2020 On Loan   6'0"  159lbs
# 2    CAM CF                          Al Hilal 2019 ~ 2022   5'4"  134lbs
# 3    CDM CM                      Swansea City 2016 ~ 2021  5'10"  152lbs
# 4    CDM CM        US Orléans Loiret Football 2018 ~ 2021  5'11"  150lbs
#
# ...

# %%
dataframe['club']= dataframe['club'].fillna('No_Club')
dataframe['club'].value_counts(dropna=False)
dataframe.isna().sum()
# Out:
# id             0
# name           0
# age            0
# nationality    0
# club           0
#               ..
# dri            0
# def            0
# phy            0
# hits           0
# ova            0
# Length: 74, dtype: int64

# %%
dataframe.club.value_counts()
# Out:
# club
# Everton           35
# Crystal Palace    35
# OGC Nice          35
# Chelsea           33
# Sporting CP       33
#                   ..
# GIF Sundsvall      1
# FC Orenburg        1
# Germany            1
# LKS Lodz           1
# Santo André        1
# Name: count, Length: 886, dtype: int64

# %%
dataframe = dataframe.rename(columns={'bp':'best_position', 'team_&_contract' :'team_and_contract', 'w/f' : 'weak_foot', 'sm' : 'skill_moves', 'a/w' : 'attacking_work_rate', 'd/w' : 'defensive_work_rate', 'ir' : 'international_reputation', 'pac' : 'pace', 'sho' : 'shooting', 'pas' : 'passing', 'dri' : 'dribbing', 'def' : 'defending', 'phy' : 'physicality', 'ova' : 'overall_rating', 'fk_accuracy' : 'free_kick_accuracy', 'gk_diving' : 'goalkeeper_diving', 'gk_handling' : 'goalkeeper_handling', 'gk_kicking' : 'goalkeeper_kicking', 'gk_positioning' : 'goalkeeper_positioning', 'gk_reflexes' : 'goalkeeper_reflexes'})
dataframe.head()
# Out:
#        id           name  age  nationality                        club  \
# 0  184383      A. Pasche   26  Switzerland           FC Lausanne-Sport
# 1  188044  Alan Carvalho   30     China PR     Beijing Sinobo Guoan FC
# 2  184431    S. Giovinco   33        Italy                    Al Hilal
# 3  233796       J. Evans   22        Wales                Swansea City
# 4  234799     Y. Demoncy   23       France  US Orléans Loiret Football
#
#   best_position  position                             team_and_contract  \
# 0            CM    CM CDM                 FC Lausanne-Sport 2015 ~ 2020
# 1            ST  ST LW LM  Beijing Sinobo Guoan FC Dec 31, 2020 On Loan
# 2           CAM    CAM CF                          Al Hilal 2019 ~ 2022
# 3           CDM    CDM CM                      Swansea City 2016 ~ 2021
# 4           CDM    CDM CM        US Orléans Loiret Football 2018 ~ 2021
#
#   height  weight   foot  growth        joined loan_date_end  value  wage  \
# ...

# %%
dataframe = dataframe.drop(columns=['id', 'team_and_contract', 'joined', 'loan_date_end', 'contract', ])
dataframe.columns

# %%
dataframe.nationality.value_counts()
# Out:
# nationality
# England                  1162
# Germany                   778
# Spain                     744
# France                    675
# Brazil                    567
#                          ...
# Saint Kitts and Nevis       1
# Qatar                       1
# Aruba                       1
# Papua New Guinea            1
# Tanzania                    1
# Name: count, Length: 159, dtype: int64
